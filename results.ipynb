# %%
# Results

import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sns

# %%
results = pd.DataFrame({'F1 score': [0.981, 0.907, 0.892],'Recall':[0.977,0.897,0.911],'Accuracy':[0.982, 0.931, 0.921],'AUC':[0.997,0.924,0.920]}) #,'Runtime':[0.19,1.09,0.087]})
results.index = ['SVM','NB','KNN']
results
# Out:
#      F1 score  Recall  Accuracy    AUC
# SVM     0.981   0.977     0.982  0.997
# NB      0.907   0.897     0.931  0.924
# KNN     0.892   0.911     0.921  0.920

# %%
models = results.columns
metric_means = {
    'SVM': [0.979, 0.978, 0.981, 0.996],
    'NB': [0.907, 0.897, 0.931, 0.924],
    'KNN': [0.892, 0.911, 0.921, 0.92]
}

errs = [
    [0.007,0.009,0.007,0.005],
    [0.013,0.019,0.009,0.010],
    [0.039,0.068,0.032,0.030]
]

x = np.arange(len(models))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained',figsize=(10,4))

for attribute, measurement in metric_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.errorbar(x + offset, measurement, linestyle="", yerr=errs[multiplier], color='black')
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Metric Value')
ax.set_title('Performance Metrics across Different Models')
ax.set_xticks(x + width, models)
ax.legend(loc='lower left')

plt.show()

# %%
b1 = plt.bar(1, 0.190,width=1,label='SVM')
plt.bar_label(b1, padding=3)
b2 = plt.bar(2,1.09,width=1,label='NB')
plt.bar_label(b2, padding=3)
b3 = plt.bar(3,0.087,width=1,label='KNN')
plt.bar_label(b3, padding=3)
plt.ylabel('Time (s)')
plt.title('Runtime across Different Models')
plt.legend()
plt.xticks([], [])
plt.ylim(0,1.2)
# Out:
# (0.0, 1.2)
